# %%
package Decomposition{
        part def Gamma{
            part def GammaModelingLanguage;
            part def ModelIntegration;
            part def SourceGeneration;
            part def Validation;
            part def Verification;
        }
}
# Out:
# Package Decomposition (8636a564-1f51-4432-a2da-3b454a6834a0)

# %%
%viz --view=TREE --style=LR Decomposition

# %%
package Decomposition{
        part def Gamma{
            part def GammaModelingLanguage{
                part def Package;
                part def Constraints;
                part def InterfaceLanguage;
                part def StatechartLanguage;
                part def CompositionLanguage;
                part def TestLanguage;

            }
            part def ModelIntegration{
                item def EngineeringModel;
                part def EngineeringModelTransformator;

            }
            part def SourceGeneration;
            part def Validation;
            part def Verification;
        }
}
# Out:
# Package Decomposition (c2672063-09d8-4e14-ba93-b1a739388383)

# %%
%viz --view=TREE --style=TB Decomposition
